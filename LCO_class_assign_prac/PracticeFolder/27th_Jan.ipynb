# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
from selenium.webdriver.support.ui import Select
executable_path = "C:\\Users\\Katlic\\Downloads\\web_drivers_chrome\\chromedriver.exe"

# %% [markdown]
# ## Conditional Commands

# %%
drivers = webdriver.Chrome(executable_path = executable_path)
drivers.get("http://newtours.demoaut.com/")
name_element = drivers.find_element_by_name("userName")
pass_element = drivers.find_element_by_name("password")
if name_element.is_displayed() and pass_element.is_displayed():
    print("Element Found")
    name_element.send_keys("mercury")
    pass_element.send_keys("mercury")
else:
    print("Element not found")
log_in_element = drivers.find_element_by_name('login').click()
trip = drivers.find_element_by_xpath('/html/body/div/table/tbody/tr/td[2]/table/tbody/tr[4]/td/table/tbody/tr/td[2]/table/tbody/tr[5]/td/form/table/tbody/tr[2]/td[2]/b/font/input[1]')
if trip.is_selected():
    print("round trip selected")
else:
    print("nothing")
time.sleep(5)
drivers.quit()
# Out:
# Element Found
# round trip selected

# %%
driver = webdriver.Chrome(executable_path = executable_path)
driver.get("http://newtours.demoaut.com/")
user_name=driver.find_element_by_xpath("/html/body/div/table/tbody/tr/td[2]/table/tbody/tr[4]/td/table/tbody/tr/td[2]/table/tbody/tr[2]/td[3]/form/table/tbody/tr[4]/td/table/tbody/tr[2]/td[2]/input")
print(user_name.is_displayed())
print(user_name.is_enabled())
password=driver.find_element_by_name('password')
if user_name.is_displayed() and password.is_displayed():
    user_name.send_keys("mercury")
    password.send_keys("mercury")
    driver.find_element_by_xpath('/html/body/div/table/tbody/tr/td[2]/table/tbody/tr[4]/td/table/tbody/tr/td[2]/table/tbody/tr[2]/td[3]/form/table/tbody/tr[4]/td/table/tbody/tr[4]/td[2]/div/input').click()
else:
    print("Something went wrong!")
# Out:
# True
# True

# %% [markdown]
# # Wait Commands

# %%
drivers = webdriver.Chrome(executable_path = executable_path)
drivers.get("http://newtours.demoaut.com/")

drivers.implicitly_wait(10)
drivers.close()

# %%
drivers = webdriver.Chrome(executable_path = executable_path)
drivers.maximize_window()
drivers.get("http://www.expedia.com")
flight_button = drivers.find_element_by_id('tab-flight-tab-hp')
flight_button.click()
one_way_trip = drivers.find_element_by_id('flight-type-one-way-label-hp-flight')
one_way_trip.click()

from_input = drivers.find_element_by_xpath("//*[@id='flight-origin-hp-flight']")
from_input.send_keys("Jaipur")

where_input = drivers.find_element_by_xpath("//*[@id='flight-destination-hp-flight']")
where_input.send_keys("Guwahati")

date_input = drivers.find_element_by_xpath("//*[@id='flight-departing-single-hp-flight']")
date_input.send_keys("02/23/2020")

where_input.click()
search_button = drivers.find_element_by_xpath("//*[@id='gcw-flights-form-hp-flight']/div[7]/label/button")
search_button.click()

time.sleep(5)
drivers.quit()
# Out:
# False True True
# False True True

# %%
### nemophee_katlic protected text

# %%
url = input("Enter your protected text url : ")
password = input("Enter your password : ")

drivers = webdriver.Chrome(executable_path = executable_path)
drivers.get("https://www.protectedtext.com/"+url)
drivers.find_element_by_id("enterpassword").send_keys(password)
drivers.find_element_by_xpath("/html/body/div[11]/div[3]/div/button").click()
for i in range(1,2):
    drivers.find_element_by_xpath("//*[@id='tabs']/ul/li[1]/span").click()
    drivers.find_element_by_xpath("/html/body/div[11]/div[3]/div/button[1]").click()
# Out:
# Enter your protected text url : nemopheekatlic
# Enter your password : heythere

# %% [markdown]
# ### spotify song list

# %%
my_Songs = []

driver = webdriver.Chrome(executable_path=executable_path)

driver.get('https://open.spotify.com/playlist/37i9dQZF1DWXJfnUiYjUKT')

# new_music_friday=driver.find_element_by_xpath('/html/body/div[2]/div/div[4]/div[3]/div[1]/div/div/section/div/section/div/div[3]/div/section/div/div[2]/div/div/div[4]')
# new_music_friday.click()

for i in range(1, 94):
    
    try:
    
        xpath = '//*[@id="main"]/div/div[4]/div[3]/div[1]/div/div/div[2]/div/section/div/div/div[2]/section/ol/div[' + str(i) + ']/div/li/div[2]/div/div[1]'
        author_xpath = '//*[@id="main"]/div/div[4]/div[3]/div[1]/div/div/div[2]/div/section/div/div/div[2]/section/ol/div[' + str(i) + ']/div/li/div[2]/div/div[2]/span[1]/span/span/a'
        time_xpath = '//*[@id="main"]/div/div[4]/div[3]/div[1]/div/div/div[2]/div/section/div/div/div[2]/section/ol/div[' + str(i) + ']/div/li/div[4]/div/span'
        elem = driver.find_element_by_xpath(xpath)
        author_xpath = driver.find_elements_by_xpath(author_xpath)
        time = driver.find_element_by_xpath(time_xpath)
        
        print(elem.text)
        for values in author_xpath:
            print(values.text, end = " ")
        print()
        print(time.text)
        
    except:
        xpath = '//*[@id="main"]/div/div[4]/div[3]/div[1]/div/div/div[2]/div/section/div/div/div[2]/section/ol/div[' + str(i) + ']/li/div[2]/div/div[1]'
        author_xpath = '//*[@id="main"]/div/div[4]/div[3]/div[1]/div/div/div[2]/div/section/div/div/div[2]/section/ol/div[' + str(i) + ']/li/div[2]/div/div[2]/span[1]/span/span/a'
        time_xpath = '//*[@id="main"]/div/div[4]/div[3]/div[1]/div/div/div[2]/div/section/div/div/div[2]/section/ol/div[' + str(i) + ']/li/div[4]/div/span'
        elem = driver.find_element_by_xpath(xpath)
        author_xpath = driver.find_elements_by_xpath(author_xpath)
        time = driver.find_element_by_xpath(time_xpath)
        
        print(elem.text)
        for value in author_xpath:
            print(value.text, end = " ")
        print()
        print(time.text)
        
    print('\n\n\n')
# Out:
# that way
# Tate McRae
# 2:55
#
#
#
#
# LOVE IN THE DARK
# Jessie Reyez
# 4:00
#
#
#
#
# B.I.T.C.H.
#
# 3:03
#
#
#
#
# What If I Told You That I Love You
# Ali Gatie
# 3:13
#
#
#
#
# Forever Yours - Avicii Tribute
# Kygo Avicii Sandro Cavazza
# 3:13
#
#
#
#
# new way
#
# 3:22
#
#
#
#
# Safety 2020
#
# 3:59
#
#
#
#
# Drugs
#
# 2:42
#
#
#
#
# Boss Bitch
# Doja Cat
# 2:14
#
#
#
#
# Neon Skyline
# Andy Shauf
# 3:38
#
#
#
#
# Mad At Me.
#
# 2:14
#
#
#
#
# Reckless Paradise
# Billy Talent
# 3:24
#
#
#
#
# Fall Apart
# Ellis
# 3:48
#
#
#
#
# Simmer
#
# 4:26
#
#
#
#
# I Don't Wanna Dance
# Shawn Hook
# 3:26
#
#
#
#
# My Frequency (feat. RebMoe)
# Tiësto 7 Skies RebMoe
# 2:21
#
#
#
#
# Nothing New
#
# 3:25
#
#
#
#
# la
# Kelsea Ballerini
# 2:46
#
#
#
#
# WHATS POPPIN
#
# 2:19
#
#
#
#
# Dance Of The Clairvoyants
# Pearl Jam
# 4:25
#
#
#
#
# Without Your Love
# Conro
# 3:08
#
#
#
#
# In These Arms
# JP Cooper
# 3:28
#
#
#
#
# Mayday!!! Fiesta Fever
# AWOLNATION Alex Ebert
# 3:42
#
#
#
#
# 2020
#
# 2:03
#
#
#
#
# U & I (feat. Goldchain)
# Sylo Nozra Goldchain
# 2:39
#
#
#
#
# More Than OK (with Clara Mae)
# R3HAB Clara Mae Frank Walker
# 2:36
#
#
#
#
# Some Kind Of Disaster
# All Time Low
# 3:43
#
#
#
#
# Wass Ties
#
# 3:21
#
#
#
#
# fever dream
# mxmtoon
# 3:16
#
#
#
#
# Mean It (feat. Wrabel)
# Cash Cash Wrabel
# 3:10
#
#
#
#
# In The Car
# Chase Rice
# 3:03
#
#
#
#
# Juro Que
# ROSALÍA
# 2:50
#
#
#
#
# This is the Place
# Tom Grennan
# 3:05
#
#
#
#
# Don't Hold Me Down
# Ryan Shepherd
# 3:11
#
#
#
#
# Under Glass
# Wolf Parade
# 3:21
#
#
#
#
# Don't Start Now - Regard Remix
# Dua Lipa Regard
# 3:08
#
#
#
#
# Broken Boy (feat. Iggy Pop)
# Cage The Elephant Iggy Pop
# 2:43
#
#
#
#
# Tommy's Intro (feat. River Tiber & Sean Leon)
# Junia-T River Tiber Sean Leon
# 4:33
#
#
#
#
# H.O.E. (Heaven On Earth)
#
# 3:11
#
#
#
#
# World Keeps Spinning
#
# 3:34
#
#
#
#
# Kissing Other People - R3HAB Remix
# Lennon Stella R3HAB
# 2:27
#
#
#
#
# Where Do We Go When We Die
#
# 3:12
#
#
#
#
# Drown (feat. Au/Ra)
# Ekali Au/Ra
# 3:01
#
#
#
#
# Trust
# Alina Baraz
# 2:35
#
#
#
#
# Cool For A Second
# Yumi Zouma
# 3:09
#
#
#
#
# Can't Go to Church
# Mitchell Tenpenny
# 4:30
#
#
#
#
# Talkin
#
# 2:05
#
#
#
#
# Lonely
# Joel Corry
# 3:10
#
#
#
#
# valentine's day
#
# 3:08
#
#
#
#
# I Feel Alive
# TOPS
# 2:34
#
#
#
#
# Shampoo Bottles
#
# 3:44
#
#
#
#
# Mind Your Business
#
# 2:29
#
#
#
#
# Rapture
#
# 3:24
#
#
#
#
# It's a Beautiful Life
# Billy Raffoul
# 2:40
#
#
#
#
# Thief
# La+ch
# 2:44
#
#
#
#
# PARADISE TO ME
# Niko Moon
# 3:36
#
#
#
#
# Hypnagogic (I Can't Wait) [edit]
# Love Regenerator Calvin Harris
# 3:13
#
#
#
#
# Morning
# Noble Oak
# 4:40
#
#
#
#
# Burn Again
# Mike Ruby
# 3:04
#
#
#
#
# My Lover
# Rainer + Grimm Charlotte Haining
# 3:42
#
#
#
#
# Hands Off Me
# Chiiild
# 3:45
#
#
#
#
# What A Drag
# Nathaniel Rateliff
# 3:34
#
#
#
#
# unforgettable
# sophie meiers
# 2:51
#
#
#
#
# High Right Now (feat. Wiz Khalifa) - Remix
#
# 2:55
#
#
#
#
# Chills
# Asher Angel
# 2:33
#
#
#
#
# buttercup
#
# 2:28
#
#
#
#
# Kameleon
# Jonny Tobin Meiwa Swatkins
# 4:06
#
#
#
#
# Baby
# Four Tet
# 4:24
#
#
#
#
# Broke Bitch
#
# 2:26
#
#
#
#
# Way You Move
# Froogle
# 2:16
#
#
#
#
# Therapist
#
# 3:03
#
#
#
#
# Another Life
# Alex Aiono Destiny Rogers
# 3:23
#
#
#
#
# Back In The Summer
# Max Frost
# 3:00
#
#
#
#
# Head Over Heels Into Heaven
# Joel Plaskett
# 3:13
#
#
#
#
# Automatic Driver
# La Roux
# 5:05
#
#
#
#
# Laughter
# Astrocolor
# 3:32
#
#
#
#
# Alone Tonight
# Aiden Myers
# 3:03
#
#
#
#
# Selling You My Heart
# Matthew Good
# 3:39
#
#
#
#
# Nostalgia For The Present Moment
# Jaunt
# 2:47
#
#
#
#
# ROYALTY
# ILIRA
# 2:45
#
#
#
#
# Wasted
# Carda Emily Falvey
# 2:45
#
#
#
#
# Sins We Made
# Harrow Fair
# 3:06
#
#
#
#
# Vanilla
# Olivia Penalva
# 3:16
#
#
#
#
# Years Ago
# Kaeley Jade
# 3:37
#
#
#
#
# Love You Like
#
# 3:30
#
#
#
#
# Terracotta
# Anthony Kalabretta
# 3:45
#
#
#
#
# You
#
# 3:33
#
#
#
#
# Moonlight
# Cassiøpeia
# 3:16
#
#
#
#
# Wait on Me
# Lisa Nicole
# 2:57
#
#
#
#
# We Cry for Harmonia
# Elephant Stone
# 4:29
#
#
#
#
# Mind Games
# Fonkynson Desiire
# 3:50
#
#
#
#
# How To Forgive
# Tennis
# 3:36
#
#
#
#
# You Lose
# Sorena
# 3:38
