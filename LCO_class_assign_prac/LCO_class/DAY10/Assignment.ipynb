# %%
print("Assignment")
# Out:
# Assignment

# %%
import requests as rq

# %%
github_user_name = "Dikhit"
github_password = "8472049800d@#"

# %%
github_api_reply = rq.get('https://api.github.com/user', auth=(github_user_name, github_password))

# %%
github_json = github_api_reply.json()

# %%
github_json
# Out:
# {'login': 'Dikhit',
#  'id': 39065753,
#  'node_id': 'MDQ6VXNlcjM5MDY1NzUz',
#  'avatar_url': 'https://avatars2.githubusercontent.com/u/39065753?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/Dikhit',
#  'html_url': 'https://github.com/Dikhit',
#  'followers_url': 'https://api.github.com/users/Dikhit/followers',
#  'following_url': 'https://api.github.com/users/Dikhit/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/Dikhit/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/Dikhit/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/Dikhit/subscriptions',
#  'organizations_url': 'https://api.github.com/users/Dikhit/orgs',
#  'repos_url': 'https://api.github.com/users/Dikhit/repos',
#  'events_url': 'https://api.github.com/users/Dikhit/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/Dikhit/received_events',
#  'type': 'User',
#  'site_admin': False,
#  'name': 'katlic',
#  'company': None,
#  'blog': '',
#  'location': None,
#  'email': None,
#  'hireable': None,
#  'bio': None,
#  'public_repos': 12,
#  'public_gists': 4,
#  'followers': 8,
#  'following': 5,
#  'created_at': '2018-05-07T18:53:09Z',
#  'updated_at': '2020-01-22T14:28:09Z',
#  'private_gists': 1,
#  'total_private_repos': 23,
#  'owned_private_repos': 19,
#  'disk_usage': 219671,
#  'collaborators': 3,
#  'two_factor_authentication': False,
#  'plan': {'name': 'free',
#   'space': 976562499,
#   'collaborators': 0,
#   'private_repos': 10000}}

# %%
github_json['login']
# Out:
# 'Dikhit'

# %%
import getpass
import requests as rq
class api_fetcher(object):
    def __init__(self):
        pass
    
    def github_fetch(self):
        user_name = input("Enter your github user name : ")
        print("Enter your top secret passwod : ",end = " ")
        
        try: 
            github_password = getpass.getpass() 
        except Exception as error: 
            print('ERROR', error)
            
        github = rq.get('https://api.github.com/user', auth=(user_name, github_password))
        print(github.status_code)
        if github.status_code == 200:
            github_data = github.json()
            print("Hey", github_data['login'])

# %%
api_obj = api_fetcher()
api_obj.github_fetch()
# Out:
# Enter your github user name : Dikhit
# Enter your top secret passwod :  ········
# Dikhit 8472049800d@#
# 200
# Hey Dikhit

# %%
p
# Out:
# 'something'

# %%
a = rq.get("https://api.github.com/users/Dikhit/repos")
b = a.json()

# %%
b
# Out:
# [{'id': 195344212,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxOTUzNDQyMTI=',
#   'name': 'block_chain_webapp',
#   'full_name': 'Dikhit/block_chain_webapp',
#   'private': False,
#   'owner': {'login': 'Dikhit',
#    'id': 39065753,
#    'node_id': 'MDQ6VXNlcjM5MDY1NzUz',
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/39065753?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Dikhit',
#    'html_url': 'https://github.com/Dikhit',
#    'followers_url': 'https://api.github.com/users/Dikhit/followers',
#    'following_url': 'https://api.github.com/users/Dikhit/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Dikhit/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Dikhit/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Dikhit/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Dikhit/orgs',
#    'repos_url': 'https://api.github.com/users/Dikhit/repos',
#    'events_url': 'https://api.github.com/users/Dikhit/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Dikhit/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/Dikhit/block_chain_webapp',
#   'description': 'block chain implementation using angularJS fetch from Savjee',
#   'fork': False,
#   'url': 'https://api.github.com/repos/Dikhit/block_chain_webapp',
#   'forks_url': 'https://api.github.com/repos/Dikhit/block_chain_webapp/forks',
#   'keys_url': 'https://api.github.com/repos/Dikhit/block_chain_webapp/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Dikhit/block_chain_webapp/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Dikhit/block_chain_webapp/teams',
#   'hooks_url': 'https://api.github.com/repos/Dikhit/block_chain_webapp/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Dikhit/block_chain_webapp/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Dikhit/block_chain_webapp/events',
#   'assignees_url': 'https://api.github.com/repos/Dikhit/block_chain_webapp/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Dikhit/block_chain_webapp/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Dikhit/block_chain_webapp/tags',
#   'blobs_url': 'https://api.github.com/repos/Dikhit/block_chain_webapp/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Dikhit/block_chain_webapp/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Dikhit/block_chain_webapp/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Dikhit/block_chain_webapp/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Dikhit/block_chain_webapp/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Dikhit/block_chain_webapp/languages',
#   'stargazers_url': 'https://api.github.com/repos/Dikhit/block_chain_webapp/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Dikhit/block_chain_webapp/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Dikhit/block_chain_webapp/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Dikhit/block_chain_webapp/subscription',
#   'commits_url': 'https://api.github.com/repos/Dikhit/block_chain_webapp/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Dikhit/block_chain_webapp/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Dikhit/block_chain_webapp/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Dikhit/block_chain_webapp/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Dikhit/block_chain_webapp/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Dikhit/block_chain_webapp/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Dikhit/block_chain_webapp/merges',
#   'archive_url': 'https://api.github.com/repos/Dikhit/block_chain_webapp/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Dikhit/block_chain_webapp/downloads',
#   'issues_url': 'https://api.github.com/repos/Dikhit/block_chain_webapp/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Dikhit/block_chain_webapp/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Dikhit/block_chain_webapp/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Dikhit/block_chain_webapp/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Dikhit/block_chain_webapp/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Dikhit/block_chain_webapp/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Dikhit/block_chain_webapp/deployments',
#   'created_at': '2019-07-05T05:29:34Z',
#   'updated_at': '2019-07-18T12:03:08Z',
#   'pushed_at': '2019-12-29T12:39:41Z',
#   'git_url': 'git://github.com/Dikhit/block_chain_webapp.git',
#   'ssh_url': 'git@github.com:Dikhit/block_chain_webapp.git',
#   'clone_url': 'https://github.com/Dikhit/block_chain_webapp.git',
#   'svn_url': 'https://github.com/Dikhit/block_chain_webapp',
#   'homepage': '',
#   'size': 345,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'TypeScript',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 2,
#   'license': None,
#   'forks': 0,
#   'open_issues': 2,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 195877247,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxOTU4NzcyNDc=',
#   'name': 'book-library-webapp',
#   'full_name': 'Dikhit/book-library-webapp',
#   'private': False,
#   'owner': {'login': 'Dikhit',
#    'id': 39065753,
#    'node_id': 'MDQ6VXNlcjM5MDY1NzUz',
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/39065753?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Dikhit',
#    'html_url': 'https://github.com/Dikhit',
#    'followers_url': 'https://api.github.com/users/Dikhit/followers',
#    'following_url': 'https://api.github.com/users/Dikhit/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Dikhit/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Dikhit/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Dikhit/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Dikhit/orgs',
#    'repos_url': 'https://api.github.com/users/Dikhit/repos',
#    'events_url': 'https://api.github.com/users/Dikhit/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Dikhit/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/Dikhit/book-library-webapp',
#   'description': 'implementation of graphql and mongoDB  and react JS as a front end',
#   'fork': False,
#   'url': 'https://api.github.com/repos/Dikhit/book-library-webapp',
#   'forks_url': 'https://api.github.com/repos/Dikhit/book-library-webapp/forks',
#   'keys_url': 'https://api.github.com/repos/Dikhit/book-library-webapp/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Dikhit/book-library-webapp/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Dikhit/book-library-webapp/teams',
#   'hooks_url': 'https://api.github.com/repos/Dikhit/book-library-webapp/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Dikhit/book-library-webapp/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Dikhit/book-library-webapp/events',
#   'assignees_url': 'https://api.github.com/repos/Dikhit/book-library-webapp/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Dikhit/book-library-webapp/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Dikhit/book-library-webapp/tags',
#   'blobs_url': 'https://api.github.com/repos/Dikhit/book-library-webapp/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Dikhit/book-library-webapp/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Dikhit/book-library-webapp/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Dikhit/book-library-webapp/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Dikhit/book-library-webapp/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Dikhit/book-library-webapp/languages',
#   'stargazers_url': 'https://api.github.com/repos/Dikhit/book-library-webapp/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Dikhit/book-library-webapp/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Dikhit/book-library-webapp/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Dikhit/book-library-webapp/subscription',
#   'commits_url': 'https://api.github.com/repos/Dikhit/book-library-webapp/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Dikhit/book-library-webapp/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Dikhit/book-library-webapp/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Dikhit/book-library-webapp/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Dikhit/book-library-webapp/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Dikhit/book-library-webapp/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Dikhit/book-library-webapp/merges',
#   'archive_url': 'https://api.github.com/repos/Dikhit/book-library-webapp/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Dikhit/book-library-webapp/downloads',
#   'issues_url': 'https://api.github.com/repos/Dikhit/book-library-webapp/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Dikhit/book-library-webapp/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Dikhit/book-library-webapp/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Dikhit/book-library-webapp/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Dikhit/book-library-webapp/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Dikhit/book-library-webapp/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Dikhit/book-library-webapp/deployments',
#   'created_at': '2019-07-08T19:53:24Z',
#   'updated_at': '2019-07-18T12:03:01Z',
#   'pushed_at': '2019-12-29T13:15:24Z',
#   'git_url': 'git://github.com/Dikhit/book-library-webapp.git',
#   'ssh_url': 'git@github.com:Dikhit/book-library-webapp.git',
#   'clone_url': 'https://github.com/Dikhit/book-library-webapp.git',
#   'svn_url': 'https://github.com/Dikhit/book-library-webapp',
#   'homepage': None,
#   'size': 27371,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'JavaScript',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 3,
#   'license': None,
#   'forks': 0,
#   'open_issues': 3,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 195338976,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxOTUzMzg5NzY=',
#   'name': 'console_blockChain',
#   'full_name': 'Dikhit/console_blockChain',
#   'private': False,
#   'owner': {'login': 'Dikhit',
#    'id': 39065753,
#    'node_id': 'MDQ6VXNlcjM5MDY1NzUz',
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/39065753?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Dikhit',
#    'html_url': 'https://github.com/Dikhit',
#    'followers_url': 'https://api.github.com/users/Dikhit/followers',
#    'following_url': 'https://api.github.com/users/Dikhit/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Dikhit/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Dikhit/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Dikhit/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Dikhit/orgs',
#    'repos_url': 'https://api.github.com/users/Dikhit/repos',
#    'events_url': 'https://api.github.com/users/Dikhit/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Dikhit/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/Dikhit/console_blockChain',
#   'description': 'block chain generator with hash key and transaction functions added',
#   'fork': False,
#   'url': 'https://api.github.com/repos/Dikhit/console_blockChain',
#   'forks_url': 'https://api.github.com/repos/Dikhit/console_blockChain/forks',
#   'keys_url': 'https://api.github.com/repos/Dikhit/console_blockChain/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Dikhit/console_blockChain/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Dikhit/console_blockChain/teams',
#   'hooks_url': 'https://api.github.com/repos/Dikhit/console_blockChain/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Dikhit/console_blockChain/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Dikhit/console_blockChain/events',
#   'assignees_url': 'https://api.github.com/repos/Dikhit/console_blockChain/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Dikhit/console_blockChain/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Dikhit/console_blockChain/tags',
#   'blobs_url': 'https://api.github.com/repos/Dikhit/console_blockChain/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Dikhit/console_blockChain/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Dikhit/console_blockChain/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Dikhit/console_blockChain/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Dikhit/console_blockChain/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Dikhit/console_blockChain/languages',
#   'stargazers_url': 'https://api.github.com/repos/Dikhit/console_blockChain/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Dikhit/console_blockChain/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Dikhit/console_blockChain/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Dikhit/console_blockChain/subscription',
#   'commits_url': 'https://api.github.com/repos/Dikhit/console_blockChain/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Dikhit/console_blockChain/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Dikhit/console_blockChain/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Dikhit/console_blockChain/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Dikhit/console_blockChain/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Dikhit/console_blockChain/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Dikhit/console_blockChain/merges',
#   'archive_url': 'https://api.github.com/repos/Dikhit/console_blockChain/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Dikhit/console_blockChain/downloads',
#   'issues_url': 'https://api.github.com/repos/Dikhit/console_blockChain/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Dikhit/console_blockChain/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Dikhit/console_blockChain/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Dikhit/console_blockChain/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Dikhit/console_blockChain/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Dikhit/console_blockChain/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Dikhit/console_blockChain/deployments',
#   'created_at': '2019-07-05T04:30:44Z',
#   'updated_at': '2019-07-18T12:03:06Z',
#   'pushed_at': '2019-07-05T04:32:26Z',
#   'git_url': 'git://github.com/Dikhit/console_blockChain.git',
#   'ssh_url': 'git@github.com:Dikhit/console_blockChain.git',
#   'clone_url': 'https://github.com/Dikhit/console_blockChain.git',
#   'svn_url': 'https://github.com/Dikhit/console_blockChain',
#   'homepage': '',
#   'size': 189,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'JavaScript',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 1,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'forks': 1,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 194890160,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxOTQ4OTAxNjA=',
#   'name': 'edmamAPI',
#   'full_name': 'Dikhit/edmamAPI',
#   'private': False,
#   'owner': {'login': 'Dikhit',
#    'id': 39065753,
#    'node_id': 'MDQ6VXNlcjM5MDY1NzUz',
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/39065753?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Dikhit',
#    'html_url': 'https://github.com/Dikhit',
#    'followers_url': 'https://api.github.com/users/Dikhit/followers',
#    'following_url': 'https://api.github.com/users/Dikhit/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Dikhit/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Dikhit/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Dikhit/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Dikhit/orgs',
#    'repos_url': 'https://api.github.com/users/Dikhit/repos',
#    'events_url': 'https://api.github.com/users/Dikhit/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Dikhit/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/Dikhit/edmamAPI',
#   'description': 'implementation of edmam_API',
#   'fork': False,
#   'url': 'https://api.github.com/repos/Dikhit/edmamAPI',
#   'forks_url': 'https://api.github.com/repos/Dikhit/edmamAPI/forks',
#   'keys_url': 'https://api.github.com/repos/Dikhit/edmamAPI/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Dikhit/edmamAPI/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Dikhit/edmamAPI/teams',
#   'hooks_url': 'https://api.github.com/repos/Dikhit/edmamAPI/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Dikhit/edmamAPI/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Dikhit/edmamAPI/events',
#   'assignees_url': 'https://api.github.com/repos/Dikhit/edmamAPI/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Dikhit/edmamAPI/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Dikhit/edmamAPI/tags',
#   'blobs_url': 'https://api.github.com/repos/Dikhit/edmamAPI/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Dikhit/edmamAPI/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Dikhit/edmamAPI/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Dikhit/edmamAPI/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Dikhit/edmamAPI/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Dikhit/edmamAPI/languages',
#   'stargazers_url': 'https://api.github.com/repos/Dikhit/edmamAPI/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Dikhit/edmamAPI/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Dikhit/edmamAPI/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Dikhit/edmamAPI/subscription',
#   'commits_url': 'https://api.github.com/repos/Dikhit/edmamAPI/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Dikhit/edmamAPI/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Dikhit/edmamAPI/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Dikhit/edmamAPI/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Dikhit/edmamAPI/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Dikhit/edmamAPI/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Dikhit/edmamAPI/merges',
#   'archive_url': 'https://api.github.com/repos/Dikhit/edmamAPI/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Dikhit/edmamAPI/downloads',
#   'issues_url': 'https://api.github.com/repos/Dikhit/edmamAPI/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Dikhit/edmamAPI/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Dikhit/edmamAPI/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Dikhit/edmamAPI/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Dikhit/edmamAPI/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Dikhit/edmamAPI/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Dikhit/edmamAPI/deployments',
#   'created_at': '2019-07-02T15:29:14Z',
#   'updated_at': '2019-07-18T12:03:05Z',
#   'pushed_at': '2019-12-29T11:35:40Z',
#   'git_url': 'git://github.com/Dikhit/edmamAPI.git',
#   'ssh_url': 'git@github.com:Dikhit/edmamAPI.git',
#   'clone_url': 'https://github.com/Dikhit/edmamAPI.git',
#   'svn_url': 'https://github.com/Dikhit/edmamAPI',
#   'homepage': None,
#   'size': 518,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'JavaScript',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 2,
#   'license': None,
#   'forks': 0,
#   'open_issues': 2,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 150927066,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxNTA5MjcwNjY=',
#   'name': 'firechat-react',
#   'full_name': 'Dikhit/firechat-react',
#   'private': False,
#   'owner': {'login': 'Dikhit',
#    'id': 39065753,
#    'node_id': 'MDQ6VXNlcjM5MDY1NzUz',
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/39065753?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Dikhit',
#    'html_url': 'https://github.com/Dikhit',
#    'followers_url': 'https://api.github.com/users/Dikhit/followers',
#    'following_url': 'https://api.github.com/users/Dikhit/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Dikhit/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Dikhit/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Dikhit/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Dikhit/orgs',
#    'repos_url': 'https://api.github.com/users/Dikhit/repos',
#    'events_url': 'https://api.github.com/users/Dikhit/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Dikhit/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/Dikhit/firechat-react',
#   'description': None,
#   'fork': True,
#   'url': 'https://api.github.com/repos/Dikhit/firechat-react',
#   'forks_url': 'https://api.github.com/repos/Dikhit/firechat-react/forks',
#   'keys_url': 'https://api.github.com/repos/Dikhit/firechat-react/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Dikhit/firechat-react/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Dikhit/firechat-react/teams',
#   'hooks_url': 'https://api.github.com/repos/Dikhit/firechat-react/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Dikhit/firechat-react/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Dikhit/firechat-react/events',
#   'assignees_url': 'https://api.github.com/repos/Dikhit/firechat-react/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Dikhit/firechat-react/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Dikhit/firechat-react/tags',
#   'blobs_url': 'https://api.github.com/repos/Dikhit/firechat-react/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Dikhit/firechat-react/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Dikhit/firechat-react/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Dikhit/firechat-react/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Dikhit/firechat-react/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Dikhit/firechat-react/languages',
#   'stargazers_url': 'https://api.github.com/repos/Dikhit/firechat-react/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Dikhit/firechat-react/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Dikhit/firechat-react/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Dikhit/firechat-react/subscription',
#   'commits_url': 'https://api.github.com/repos/Dikhit/firechat-react/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Dikhit/firechat-react/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Dikhit/firechat-react/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Dikhit/firechat-react/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Dikhit/firechat-react/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Dikhit/firechat-react/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Dikhit/firechat-react/merges',
#   'archive_url': 'https://api.github.com/repos/Dikhit/firechat-react/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Dikhit/firechat-react/downloads',
#   'issues_url': 'https://api.github.com/repos/Dikhit/firechat-react/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Dikhit/firechat-react/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Dikhit/firechat-react/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Dikhit/firechat-react/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Dikhit/firechat-react/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Dikhit/firechat-react/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Dikhit/firechat-react/deployments',
#   'created_at': '2018-09-30T03:34:06Z',
#   'updated_at': '2019-07-18T12:02:56Z',
#   'pushed_at': '2018-03-14T11:10:11Z',
#   'git_url': 'git://github.com/Dikhit/firechat-react.git',
#   'ssh_url': 'git@github.com:Dikhit/firechat-react.git',
#   'clone_url': 'https://github.com/Dikhit/firechat-react.git',
#   'svn_url': 'https://github.com/Dikhit/firechat-react',
#   'homepage': None,
#   'size': 324,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'JavaScript',
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 201605349,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyMDE2MDUzNDk=',
#   'name': 'hornbill-components',
#   'full_name': 'Dikhit/hornbill-components',
#   'private': False,
#   'owner': {'login': 'Dikhit',
#    'id': 39065753,
#    'node_id': 'MDQ6VXNlcjM5MDY1NzUz',
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/39065753?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Dikhit',
#    'html_url': 'https://github.com/Dikhit',
#    'followers_url': 'https://api.github.com/users/Dikhit/followers',
#    'following_url': 'https://api.github.com/users/Dikhit/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Dikhit/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Dikhit/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Dikhit/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Dikhit/orgs',
#    'repos_url': 'https://api.github.com/users/Dikhit/repos',
#    'events_url': 'https://api.github.com/users/Dikhit/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Dikhit/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/Dikhit/hornbill-components',
#   'description': None,
#   'fork': True,
#   'url': 'https://api.github.com/repos/Dikhit/hornbill-components',
#   'forks_url': 'https://api.github.com/repos/Dikhit/hornbill-components/forks',
#   'keys_url': 'https://api.github.com/repos/Dikhit/hornbill-components/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Dikhit/hornbill-components/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Dikhit/hornbill-components/teams',
#   'hooks_url': 'https://api.github.com/repos/Dikhit/hornbill-components/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Dikhit/hornbill-components/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Dikhit/hornbill-components/events',
#   'assignees_url': 'https://api.github.com/repos/Dikhit/hornbill-components/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Dikhit/hornbill-components/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Dikhit/hornbill-components/tags',
#   'blobs_url': 'https://api.github.com/repos/Dikhit/hornbill-components/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Dikhit/hornbill-components/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Dikhit/hornbill-components/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Dikhit/hornbill-components/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Dikhit/hornbill-components/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Dikhit/hornbill-components/languages',
#   'stargazers_url': 'https://api.github.com/repos/Dikhit/hornbill-components/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Dikhit/hornbill-components/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Dikhit/hornbill-components/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Dikhit/hornbill-components/subscription',
#   'commits_url': 'https://api.github.com/repos/Dikhit/hornbill-components/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Dikhit/hornbill-components/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Dikhit/hornbill-components/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Dikhit/hornbill-components/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Dikhit/hornbill-components/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Dikhit/hornbill-components/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Dikhit/hornbill-components/merges',
#   'archive_url': 'https://api.github.com/repos/Dikhit/hornbill-components/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Dikhit/hornbill-components/downloads',
#   'issues_url': 'https://api.github.com/repos/Dikhit/hornbill-components/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Dikhit/hornbill-components/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Dikhit/hornbill-components/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Dikhit/hornbill-components/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Dikhit/hornbill-components/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Dikhit/hornbill-components/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Dikhit/hornbill-components/deployments',
#   'created_at': '2019-08-10T08:57:23Z',
#   'updated_at': '2019-08-19T18:35:01Z',
#   'pushed_at': '2019-08-19T18:34:59Z',
#   'git_url': 'git://github.com/Dikhit/hornbill-components.git',
#   'ssh_url': 'git@github.com:Dikhit/hornbill-components.git',
#   'clone_url': 'https://github.com/Dikhit/hornbill-components.git',
#   'svn_url': 'https://github.com/Dikhit/hornbill-components',
#   'homepage': None,
#   'size': 7969,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'CSS',
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 209144934,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyMDkxNDQ5MzQ=',
#   'name': 'katlic-contact-manager',
#   'full_name': 'Dikhit/katlic-contact-manager',
#   'private': False,
#   'owner': {'login': 'Dikhit',
#    'id': 39065753,
#    'node_id': 'MDQ6VXNlcjM5MDY1NzUz',
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/39065753?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Dikhit',
#    'html_url': 'https://github.com/Dikhit',
#    'followers_url': 'https://api.github.com/users/Dikhit/followers',
#    'following_url': 'https://api.github.com/users/Dikhit/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Dikhit/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Dikhit/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Dikhit/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Dikhit/orgs',
#    'repos_url': 'https://api.github.com/users/Dikhit/repos',
#    'events_url': 'https://api.github.com/users/Dikhit/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Dikhit/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/Dikhit/katlic-contact-manager',
#   'description': 'contact management app with the functionalities... using react native ',
#   'fork': False,
#   'url': 'https://api.github.com/repos/Dikhit/katlic-contact-manager',
#   'forks_url': 'https://api.github.com/repos/Dikhit/katlic-contact-manager/forks',
#   'keys_url': 'https://api.github.com/repos/Dikhit/katlic-contact-manager/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Dikhit/katlic-contact-manager/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Dikhit/katlic-contact-manager/teams',
#   'hooks_url': 'https://api.github.com/repos/Dikhit/katlic-contact-manager/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Dikhit/katlic-contact-manager/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Dikhit/katlic-contact-manager/events',
#   'assignees_url': 'https://api.github.com/repos/Dikhit/katlic-contact-manager/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Dikhit/katlic-contact-manager/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Dikhit/katlic-contact-manager/tags',
#   'blobs_url': 'https://api.github.com/repos/Dikhit/katlic-contact-manager/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Dikhit/katlic-contact-manager/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Dikhit/katlic-contact-manager/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Dikhit/katlic-contact-manager/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Dikhit/katlic-contact-manager/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Dikhit/katlic-contact-manager/languages',
#   'stargazers_url': 'https://api.github.com/repos/Dikhit/katlic-contact-manager/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Dikhit/katlic-contact-manager/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Dikhit/katlic-contact-manager/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Dikhit/katlic-contact-manager/subscription',
#   'commits_url': 'https://api.github.com/repos/Dikhit/katlic-contact-manager/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Dikhit/katlic-contact-manager/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Dikhit/katlic-contact-manager/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Dikhit/katlic-contact-manager/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Dikhit/katlic-contact-manager/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Dikhit/katlic-contact-manager/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Dikhit/katlic-contact-manager/merges',
#   'archive_url': 'https://api.github.com/repos/Dikhit/katlic-contact-manager/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Dikhit/katlic-contact-manager/downloads',
#   'issues_url': 'https://api.github.com/repos/Dikhit/katlic-contact-manager/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Dikhit/katlic-contact-manager/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Dikhit/katlic-contact-manager/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Dikhit/katlic-contact-manager/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Dikhit/katlic-contact-manager/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Dikhit/katlic-contact-manager/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Dikhit/katlic-contact-manager/deployments',
#   'created_at': '2019-09-17T19:56:01Z',
#   'updated_at': '2019-09-28T09:59:56Z',
#   'pushed_at': '2019-09-18T06:37:35Z',
#   'git_url': 'git://github.com/Dikhit/katlic-contact-manager.git',
#   'ssh_url': 'git@github.com:Dikhit/katlic-contact-manager.git',
#   'clone_url': 'https://github.com/Dikhit/katlic-contact-manager.git',
#   'svn_url': 'https://github.com/Dikhit/katlic-contact-manager',
#   'homepage': '',
#   'size': 108,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'JavaScript',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 209303182,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyMDkzMDMxODI=',
#   'name': 'Katlic-Evernote-Clone',
#   'full_name': 'Dikhit/Katlic-Evernote-Clone',
#   'private': False,
#   'owner': {'login': 'Dikhit',
#    'id': 39065753,
#    'node_id': 'MDQ6VXNlcjM5MDY1NzUz',
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/39065753?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Dikhit',
#    'html_url': 'https://github.com/Dikhit',
#    'followers_url': 'https://api.github.com/users/Dikhit/followers',
#    'following_url': 'https://api.github.com/users/Dikhit/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Dikhit/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Dikhit/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Dikhit/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Dikhit/orgs',
#    'repos_url': 'https://api.github.com/users/Dikhit/repos',
#    'events_url': 'https://api.github.com/users/Dikhit/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Dikhit/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/Dikhit/Katlic-Evernote-Clone',
#   'description': 'it is a ever note clone.... using reactJS as a front End and firebase as a database...',
#   'fork': False,
#   'url': 'https://api.github.com/repos/Dikhit/Katlic-Evernote-Clone',
#   'forks_url': 'https://api.github.com/repos/Dikhit/Katlic-Evernote-Clone/forks',
#   'keys_url': 'https://api.github.com/repos/Dikhit/Katlic-Evernote-Clone/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Dikhit/Katlic-Evernote-Clone/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Dikhit/Katlic-Evernote-Clone/teams',
#   'hooks_url': 'https://api.github.com/repos/Dikhit/Katlic-Evernote-Clone/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Dikhit/Katlic-Evernote-Clone/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Dikhit/Katlic-Evernote-Clone/events',
#   'assignees_url': 'https://api.github.com/repos/Dikhit/Katlic-Evernote-Clone/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Dikhit/Katlic-Evernote-Clone/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Dikhit/Katlic-Evernote-Clone/tags',
#   'blobs_url': 'https://api.github.com/repos/Dikhit/Katlic-Evernote-Clone/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Dikhit/Katlic-Evernote-Clone/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Dikhit/Katlic-Evernote-Clone/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Dikhit/Katlic-Evernote-Clone/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Dikhit/Katlic-Evernote-Clone/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Dikhit/Katlic-Evernote-Clone/languages',
#   'stargazers_url': 'https://api.github.com/repos/Dikhit/Katlic-Evernote-Clone/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Dikhit/Katlic-Evernote-Clone/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Dikhit/Katlic-Evernote-Clone/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Dikhit/Katlic-Evernote-Clone/subscription',
#   'commits_url': 'https://api.github.com/repos/Dikhit/Katlic-Evernote-Clone/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Dikhit/Katlic-Evernote-Clone/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Dikhit/Katlic-Evernote-Clone/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Dikhit/Katlic-Evernote-Clone/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Dikhit/Katlic-Evernote-Clone/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Dikhit/Katlic-Evernote-Clone/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Dikhit/Katlic-Evernote-Clone/merges',
#   'archive_url': 'https://api.github.com/repos/Dikhit/Katlic-Evernote-Clone/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Dikhit/Katlic-Evernote-Clone/downloads',
#   'issues_url': 'https://api.github.com/repos/Dikhit/Katlic-Evernote-Clone/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Dikhit/Katlic-Evernote-Clone/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Dikhit/Katlic-Evernote-Clone/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Dikhit/Katlic-Evernote-Clone/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Dikhit/Katlic-Evernote-Clone/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Dikhit/Katlic-Evernote-Clone/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Dikhit/Katlic-Evernote-Clone/deployments',
#   'created_at': '2019-09-18T12:29:28Z',
#   'updated_at': '2019-10-03T10:13:38Z',
#   'pushed_at': '2019-12-30T01:08:38Z',
#   'git_url': 'git://github.com/Dikhit/Katlic-Evernote-Clone.git',
#   'ssh_url': 'git@github.com:Dikhit/Katlic-Evernote-Clone.git',
#   'clone_url': 'https://github.com/Dikhit/Katlic-Evernote-Clone.git',
#   'svn_url': 'https://github.com/Dikhit/Katlic-Evernote-Clone',
#   'homepage': '',
#   'size': 599,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'JavaScript',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 1,
#   'license': None,
#   'forks': 0,
#   'open_issues': 1,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 201791981,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyMDE3OTE5ODE=',
#   'name': 'restAPI',
#   'full_name': 'Dikhit/restAPI',
#   'private': False,
#   'owner': {'login': 'Dikhit',
#    'id': 39065753,
#    'node_id': 'MDQ6VXNlcjM5MDY1NzUz',
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/39065753?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Dikhit',
#    'html_url': 'https://github.com/Dikhit',
#    'followers_url': 'https://api.github.com/users/Dikhit/followers',
#    'following_url': 'https://api.github.com/users/Dikhit/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Dikhit/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Dikhit/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Dikhit/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Dikhit/orgs',
#    'repos_url': 'https://api.github.com/users/Dikhit/repos',
#    'events_url': 'https://api.github.com/users/Dikhit/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Dikhit/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/Dikhit/restAPI',
#   'description': 'authentication rest API using jwt .. nodeJS ',
#   'fork': False,
#   'url': 'https://api.github.com/repos/Dikhit/restAPI',
#   'forks_url': 'https://api.github.com/repos/Dikhit/restAPI/forks',
#   'keys_url': 'https://api.github.com/repos/Dikhit/restAPI/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Dikhit/restAPI/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Dikhit/restAPI/teams',
#   'hooks_url': 'https://api.github.com/repos/Dikhit/restAPI/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Dikhit/restAPI/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Dikhit/restAPI/events',
#   'assignees_url': 'https://api.github.com/repos/Dikhit/restAPI/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Dikhit/restAPI/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Dikhit/restAPI/tags',
#   'blobs_url': 'https://api.github.com/repos/Dikhit/restAPI/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Dikhit/restAPI/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Dikhit/restAPI/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Dikhit/restAPI/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Dikhit/restAPI/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Dikhit/restAPI/languages',
#   'stargazers_url': 'https://api.github.com/repos/Dikhit/restAPI/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Dikhit/restAPI/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Dikhit/restAPI/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Dikhit/restAPI/subscription',
#   'commits_url': 'https://api.github.com/repos/Dikhit/restAPI/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Dikhit/restAPI/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Dikhit/restAPI/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Dikhit/restAPI/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Dikhit/restAPI/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Dikhit/restAPI/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Dikhit/restAPI/merges',
#   'archive_url': 'https://api.github.com/repos/Dikhit/restAPI/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Dikhit/restAPI/downloads',
#   'issues_url': 'https://api.github.com/repos/Dikhit/restAPI/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Dikhit/restAPI/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Dikhit/restAPI/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Dikhit/restAPI/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Dikhit/restAPI/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Dikhit/restAPI/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Dikhit/restAPI/deployments',
#   'created_at': '2019-08-11T16:59:51Z',
#   'updated_at': '2019-09-28T10:04:19Z',
#   'pushed_at': '2019-11-05T22:12:42Z',
#   'git_url': 'git://github.com/Dikhit/restAPI.git',
#   'ssh_url': 'git@github.com:Dikhit/restAPI.git',
#   'clone_url': 'https://github.com/Dikhit/restAPI.git',
# ...
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 196699788,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxOTY2OTk3ODg=',
#   'name': 'shopping_desktop_App',
#   'full_name': 'Dikhit/shopping_desktop_App',
#   'private': False,
#   'owner': {'login': 'Dikhit',
#    'id': 39065753,
#    'node_id': 'MDQ6VXNlcjM5MDY1NzUz',
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/39065753?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Dikhit',
#    'html_url': 'https://github.com/Dikhit',
#    'followers_url': 'https://api.github.com/users/Dikhit/followers',
#    'following_url': 'https://api.github.com/users/Dikhit/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Dikhit/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Dikhit/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Dikhit/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Dikhit/orgs',
#    'repos_url': 'https://api.github.com/users/Dikhit/repos',
#    'events_url': 'https://api.github.com/users/Dikhit/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Dikhit/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/Dikhit/shopping_desktop_App',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/Dikhit/shopping_desktop_App',
#   'forks_url': 'https://api.github.com/repos/Dikhit/shopping_desktop_App/forks',
#   'keys_url': 'https://api.github.com/repos/Dikhit/shopping_desktop_App/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Dikhit/shopping_desktop_App/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Dikhit/shopping_desktop_App/teams',
#   'hooks_url': 'https://api.github.com/repos/Dikhit/shopping_desktop_App/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Dikhit/shopping_desktop_App/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Dikhit/shopping_desktop_App/events',
#   'assignees_url': 'https://api.github.com/repos/Dikhit/shopping_desktop_App/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Dikhit/shopping_desktop_App/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Dikhit/shopping_desktop_App/tags',
#   'blobs_url': 'https://api.github.com/repos/Dikhit/shopping_desktop_App/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Dikhit/shopping_desktop_App/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Dikhit/shopping_desktop_App/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Dikhit/shopping_desktop_App/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Dikhit/shopping_desktop_App/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Dikhit/shopping_desktop_App/languages',
#   'stargazers_url': 'https://api.github.com/repos/Dikhit/shopping_desktop_App/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Dikhit/shopping_desktop_App/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Dikhit/shopping_desktop_App/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Dikhit/shopping_desktop_App/subscription',
#   'commits_url': 'https://api.github.com/repos/Dikhit/shopping_desktop_App/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Dikhit/shopping_desktop_App/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Dikhit/shopping_desktop_App/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Dikhit/shopping_desktop_App/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Dikhit/shopping_desktop_App/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Dikhit/shopping_desktop_App/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Dikhit/shopping_desktop_App/merges',
#   'archive_url': 'https://api.github.com/repos/Dikhit/shopping_desktop_App/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Dikhit/shopping_desktop_App/downloads',
#   'issues_url': 'https://api.github.com/repos/Dikhit/shopping_desktop_App/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Dikhit/shopping_desktop_App/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Dikhit/shopping_desktop_App/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Dikhit/shopping_desktop_App/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Dikhit/shopping_desktop_App/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Dikhit/shopping_desktop_App/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Dikhit/shopping_desktop_App/deployments',
#   'created_at': '2019-07-13T08:50:26Z',
#   'updated_at': '2019-07-18T12:03:03Z',
#   'pushed_at': '2019-07-13T09:00:56Z',
#   'git_url': 'git://github.com/Dikhit/shopping_desktop_App.git',
#   'ssh_url': 'git@github.com:Dikhit/shopping_desktop_App.git',
#   'clone_url': 'https://github.com/Dikhit/shopping_desktop_App.git',
#   'svn_url': 'https://github.com/Dikhit/shopping_desktop_App',
#   'homepage': None,
#   'size': 49073,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'JavaScript',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 213206710,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyMTMyMDY3MTA=',
#   'name': 'sister_portfolio',
#   'full_name': 'Dikhit/sister_portfolio',
#   'private': False,
#   'owner': {'login': 'Dikhit',
#    'id': 39065753,
#    'node_id': 'MDQ6VXNlcjM5MDY1NzUz',
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/39065753?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Dikhit',
#    'html_url': 'https://github.com/Dikhit',
#    'followers_url': 'https://api.github.com/users/Dikhit/followers',
#    'following_url': 'https://api.github.com/users/Dikhit/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Dikhit/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Dikhit/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Dikhit/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Dikhit/orgs',
#    'repos_url': 'https://api.github.com/users/Dikhit/repos',
#    'events_url': 'https://api.github.com/users/Dikhit/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Dikhit/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/Dikhit/sister_portfolio',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/Dikhit/sister_portfolio',
#   'forks_url': 'https://api.github.com/repos/Dikhit/sister_portfolio/forks',
#   'keys_url': 'https://api.github.com/repos/Dikhit/sister_portfolio/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Dikhit/sister_portfolio/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Dikhit/sister_portfolio/teams',
#   'hooks_url': 'https://api.github.com/repos/Dikhit/sister_portfolio/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Dikhit/sister_portfolio/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Dikhit/sister_portfolio/events',
#   'assignees_url': 'https://api.github.com/repos/Dikhit/sister_portfolio/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Dikhit/sister_portfolio/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Dikhit/sister_portfolio/tags',
#   'blobs_url': 'https://api.github.com/repos/Dikhit/sister_portfolio/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Dikhit/sister_portfolio/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Dikhit/sister_portfolio/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Dikhit/sister_portfolio/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Dikhit/sister_portfolio/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Dikhit/sister_portfolio/languages',
#   'stargazers_url': 'https://api.github.com/repos/Dikhit/sister_portfolio/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Dikhit/sister_portfolio/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Dikhit/sister_portfolio/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Dikhit/sister_portfolio/subscription',
#   'commits_url': 'https://api.github.com/repos/Dikhit/sister_portfolio/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Dikhit/sister_portfolio/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Dikhit/sister_portfolio/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Dikhit/sister_portfolio/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Dikhit/sister_portfolio/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Dikhit/sister_portfolio/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Dikhit/sister_portfolio/merges',
#   'archive_url': 'https://api.github.com/repos/Dikhit/sister_portfolio/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Dikhit/sister_portfolio/downloads',
#   'issues_url': 'https://api.github.com/repos/Dikhit/sister_portfolio/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Dikhit/sister_portfolio/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Dikhit/sister_portfolio/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Dikhit/sister_portfolio/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Dikhit/sister_portfolio/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Dikhit/sister_portfolio/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Dikhit/sister_portfolio/deployments',
#   'created_at': '2019-10-06T16:51:30Z',
#   'updated_at': '2019-11-04T11:29:02Z',
#   'pushed_at': '2019-11-04T11:29:01Z',
#   'git_url': 'git://github.com/Dikhit/sister_portfolio.git',
#   'ssh_url': 'git@github.com:Dikhit/sister_portfolio.git',
#   'clone_url': 'https://github.com/Dikhit/sister_portfolio.git',
#   'svn_url': 'https://github.com/Dikhit/sister_portfolio',
#   'homepage': None,
#   'size': 3662,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'HTML',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 208395884,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyMDgzOTU4ODQ=',
#   'name': 'unityCamera',
#   'full_name': 'Dikhit/unityCamera',
#   'private': False,
#   'owner': {'login': 'Dikhit',
#    'id': 39065753,
#    'node_id': 'MDQ6VXNlcjM5MDY1NzUz',
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/39065753?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Dikhit',
#    'html_url': 'https://github.com/Dikhit',
#    'followers_url': 'https://api.github.com/users/Dikhit/followers',
#    'following_url': 'https://api.github.com/users/Dikhit/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Dikhit/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Dikhit/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Dikhit/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Dikhit/orgs',
#    'repos_url': 'https://api.github.com/users/Dikhit/repos',
#    'events_url': 'https://api.github.com/users/Dikhit/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Dikhit/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/Dikhit/unityCamera',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/Dikhit/unityCamera',
#   'forks_url': 'https://api.github.com/repos/Dikhit/unityCamera/forks',
#   'keys_url': 'https://api.github.com/repos/Dikhit/unityCamera/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Dikhit/unityCamera/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Dikhit/unityCamera/teams',
#   'hooks_url': 'https://api.github.com/repos/Dikhit/unityCamera/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Dikhit/unityCamera/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Dikhit/unityCamera/events',
#   'assignees_url': 'https://api.github.com/repos/Dikhit/unityCamera/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Dikhit/unityCamera/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Dikhit/unityCamera/tags',
#   'blobs_url': 'https://api.github.com/repos/Dikhit/unityCamera/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Dikhit/unityCamera/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Dikhit/unityCamera/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Dikhit/unityCamera/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Dikhit/unityCamera/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Dikhit/unityCamera/languages',
#   'stargazers_url': 'https://api.github.com/repos/Dikhit/unityCamera/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Dikhit/unityCamera/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Dikhit/unityCamera/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Dikhit/unityCamera/subscription',
#   'commits_url': 'https://api.github.com/repos/Dikhit/unityCamera/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Dikhit/unityCamera/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Dikhit/unityCamera/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Dikhit/unityCamera/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Dikhit/unityCamera/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Dikhit/unityCamera/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Dikhit/unityCamera/merges',
#   'archive_url': 'https://api.github.com/repos/Dikhit/unityCamera/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Dikhit/unityCamera/downloads',
#   'issues_url': 'https://api.github.com/repos/Dikhit/unityCamera/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Dikhit/unityCamera/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Dikhit/unityCamera/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Dikhit/unityCamera/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Dikhit/unityCamera/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Dikhit/unityCamera/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Dikhit/unityCamera/deployments',
#   'created_at': '2019-09-14T05:52:51Z',
#   'updated_at': '2019-09-14T05:54:37Z',
#   'pushed_at': '2019-09-14T05:54:35Z',
#   'git_url': 'git://github.com/Dikhit/unityCamera.git',
#   'ssh_url': 'git@github.com:Dikhit/unityCamera.git',
#   'clone_url': 'https://github.com/Dikhit/unityCamera.git',
#   'svn_url': 'https://github.com/Dikhit/unityCamera',
#   'homepage': None,
#   'size': 98,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'JavaScript',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'}]

# %%
import geocoder
g = geocoder.ip('me')
print(g.latlng)
# Out:
# [26.9196, 75.7878]

# %%
import requests as rq
import getpass

user_name=input("Enter your Github username: ")
Password = print("Enter your password:")

try: 
    password = getpass.getpass() 
except Exception as error: 
    print('ERROR', error)


url = rq.get('https://api.github.com/user', auth=(user_name, password))

data = url.json()

print(data)
# Name = data['login']
# Username = data['name']
# Location = data['location']
# public_repo = data['public_repos']
# Followers = data['followers']


# print('Name: {}'.format(Name))
# print('Username: {}'.format(Username))
# print('Location: {}'.format(Location))
# print('public_repo: {}'.format(public_repo))
# print('Followers: {}'.format(Followers))
# Out:
# Enter your Github username: Dikhit
# Enter your password:
# ········
# {'message': 'Bad credentials', 'documentation_url': 'https://developer.github.com/v3'}

# %%
def hello():
    return "Hello"

# %%
hello_var = hello()

# %%
hello_var
# Out:
# 'Hello'

# %%
string_len=int(input("Enter string length : "))
string=input("Enter the string : ")

some_String = "hackerearth"
my_var = set(some_String)
# Out:
# Enter string length : 2
# Enter the string : hackerearth

# %%
my_var
# Out:
# {'a', 'c', 'e', 'h', 'k', 'r', 't'}
