# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import math

# %% [markdown]
# ## Edureka Tutorial Open CV

# %%
grey_img = cv2.imread("1.jpg",0)

# %%
plt.imshow(grey_img)

# %%
img = cv2.imread("1.jpg",1)

# %%
plt.imshow(img)

# %%
print(grey_img.shape, img.shape)
# Out:
# (355, 500) (355, 500, 3)

# %%
cv2.imshow("image", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
resized_img = cv2.resize(img, (int(img.shape[1]/2),int(img.shape[0]/2))) 
plt.imshow(resized_img)

# %%
np.full((3,3), 99, dtype="complex")
# Out:
# array([[99.+0.j, 99.+0.j, 99.+0.j],
#        [99.+0.j, 99.+0.j, 99.+0.j],
#        [99.+0.j, 99.+0.j, 99.+0.j]])

# %%
x = np.full((4,4), 55, dtype="int32")

# %%
x
# Out:
# array([[55, 55, 55, 55],
#        [55, 55, 55, 55],
#        [55, 55, 55, 55],
#        [55, 55, 55, 55]])

# %%
x.reshape(8,2)
# Out:
# array([[55, 55],
#        [55, 55],
#        [55, 55],
#        [55, 55],
#        [55, 55],
#        [55, 55],
#        [55, 55],
#        [55, 55]])

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
import numpy as np

# %%
def get_test_data(delta=0.05):
    from matplotlib.mlab import bivariate_normal
    x = y = np.arrange(-3.0, 3.0, delta)
    X,Y = np.meshgrid(x,y)
    
    Z1 = bivariate_normal(X,Y, 1.0,1.0,0.0,0.0)
    Z2 = bivariate_normal(X,Y, 1.5,0.5,1.0,1.0)
    
    z = Z2 - Z1
    
    X = X * 10
    Y = Y * 10
    Z = Z * 500
    return X, Y, Z

# %%
fig = plt.figure()
ax= fig.add_subplot(111, projection='3d')

x,y,z = axes3d.get_test_data(0.05)
ax.plot_wireframe(x,y,z, rstride = 10, cstride = 10)
plt.show()

# %%
resized_img = cv2.resize(img, (int(grey_img.shape[1]*2),int(grey_img.shape[0]*2))) 
plt.imshow(resized_img)

# %%
print(cv2.__version__)
# Out:
# 4.1.2

# %%
img = cv2.imread("1.jpg", 55)

# %%
plt.imshow(img)
