# %%
def array_func(array):
    for i in range(len(array) - 1):
        for j in range(len(array) - i- 1):
            if array[j] > array[j+1]:
                array[j], array[j+1] = array[j+1], array[j]
    return array

# %%
array_func([1,2])
# Out:
# [1, 2]

# %%
print("Selenium")
# Out:
# Selenium

# %%
from selenium import webdriver

# %%
driver = webdriver.chrome()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-d2a3abf43f69> in <module>
# ----> 1 driver = webdriver.chrome()
#
# TypeError: 'module' object is not callable

# %%
def check(string) :  
    p = set(string)  
    s = {'0', '1'}  
    
    if s == p or p == {'0'} or p == {'1'}: 
        return True
    else : 
        return False

# %%
num_test_case = int(input("Enter the number of test case : "))
while num_test_case > 0:
    binary_number = 0
    input_number = input("Enter the number : ")
    power = len(input_number)
    if check(input_number):
        for index,value in enumerate(input_number):
            power = power - 1
            binary_number = binary_number +  ( (2**power) * int(value))
        print(binary_number)
    num_test_case -= 1

# %%
heigth = int(input("Enter the height : "))
for iterator in range(1,heigth+1):
    if iterator < 4:
        print(iterator,"1"*iterator, end = "\n")
    else:
        if iterator % 2 == 0:
            print(iterator,"1", end="")
            print("0"*(iterator - 2), end="")
            print("1")
        else:
            print(iterator,"1"*iterator)
# Out:
# Enter the height : 123
# 1 1
# 2 11
# 3 111
# 4 1001
# 5 11111
# 6 100001
# 7 1111111
# 8 10000001
# 9 111111111
# 10 1000000001
# 11 11111111111
# 12 100000000001
# 13 1111111111111
# 14 10000000000001
# 15 111111111111111
# 16 1000000000000001
# 17 11111111111111111
# 18 100000000000000001
# 19 1111111111111111111
# 20 10000000000000000001
# 21 111111111111111111111
# 22 1000000000000000000001
# 23 11111111111111111111111
# 24 100000000000000000000001
# 25 1111111111111111111111111
# 26 10000000000000000000000001
# 27 111111111111111111111111111
# 28 1000000000000000000000000001
# 29 11111111111111111111111111111
# 30 100000000000000000000000000001
# 31 1111111111111111111111111111111
# 32 10000000000000000000000000000001
# 33 111111111111111111111111111111111
# 34 1000000000000000000000000000000001
# 35 11111111111111111111111111111111111
# 36 100000000000000000000000000000000001
# 37 1111111111111111111111111111111111111
# 38 10000000000000000000000000000000000001
# ...

# %%
input_height = int(input("Enter the height : "))
for iterator in range(1,input_height+1):
    if iterator == 1:
        print("1")
    elif iterator == 2:
        print("11")
    else:
        print(str(iterator-1),end="")
        print("0"*(iterator-2), end = "")
        print(str(iterator-1))
# Out:
# Enter the height : 10
# 1
# 22
# 202
# 3003
# 40004
# 500005
# 6000006
# 70000007
# 800000008
# 9000000009

# %%
input_length = int(input("Enter the length : "))
value = input_length - 1
stars = input_length - 1
first_line = (input_length * 2) -1
for iterator in range(1,input_length*2):
    if value > 0:
        i = 1
        if iterator == 1:
            print("*"*first_line)
        counter = 0
        while counter < 2:
            print("*"*value, end = "")
            print(' '*i, end="")
            i += 2
            counter +=1
        print()
    value -= 1
# Out:
# Enter the length : 5
# *********
# **** ****
# *** ***
# ** **
# * *

# %%
input_length = int(input("Enter the length : "))
value = input_length - 1
stars = input_length - 1
first_line = (input_length * 2) -1
space = ' '
i = 1
first_half = True
for iterator in range(1,input_length*2):
    if first_half:
        if iterator == 1:
            print("*"*first_line)
            
        print("*"*value, end = "")
        print(" "*i, end="")
        print("*"*value, end = "\n")
        i += 2
        value -= 1
        if value == 1:
            first_half = False
    elif not first_half:
        value = value + 1
        i = i - 2
        print("*"*value, end = "")
        print(" "*i, end ="")
        print("*"*value, end="\n")
        if value == 4:
            print("*"*first_line)
            break
# Out:
# Enter the length : 5
# *********
# **** ****
# ***   ***
# **     **
# **     **
# ***   ***
# **** ****
# *********

# %%
print(" "* 25, end = "Hello")
# Out:
#                          Hello
