# %%
print("openCV basics")
# Out:
# openCV basics

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img = cv2.imread("a.jpg")

# %%
plt.imshow(img)

# %%
grey_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(grey_img, cmap='gray')

# %%
plt.imshow(grey_img)

# %%
cv2.imwrite("Gray.jpg", grey_img)
# Out:
# True

# %%
img.shape
# Out:
# (2160, 3840, 3)

# %%
img[0][0]
# Out:
# array([26, 40, 63], dtype=uint8)

# %%
img[0][0][0]
# Out:
# 26

# %%
sum =0
for i in range(2161):
    sum = sum + img[0][i][0]*0.144

sum1 = 0
for i in range(3841):
    sum1 = sum1 + int(img[0][i][0])*0.114
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-25-ccea76c7cce6> in <module>
#       5 sum1 = 0
#       6 for i in range(3841):
# ----> 7     sum1 = sum1 + int(img[0][i][0])*0.114
#
# IndexError: index 3840 is out of bounds for axis 0 with size 3840

# %%
sum1
# Out:
# 7682

# %%
new_image = img
for i in range(2160):
    for j in range(3840):
        new_image[i][j][0] = img[i][j][0]*0.114
        new_image[i][j][1] = img[i][j][1]*0.587
        new_image[i][j][2] = img[i][j][2]*0.299

# %%
i_g = img
for i in range(380):
    for j in range(287):
        i_g[i][j][0] = img[i][j][0]*0.0722
        i_g[i][j][1] = img[i][j][1]*0.7152
        i_g[i][j][2] = img[i][j][2]*0.2126
# Out:
# array([[[  1,  28,  13],
#         [  1,  27,  13],
#         [  1,  28,  13],
#         ...,
#         [ 41,  51,  69],
#         [ 42,  50,  73],
#         [ 43,  53,  77]],
#
#        [[  1,  27,  13],
#         [  1,  28,  13],
#         [  2,  28,  13],
#         ...,
#         [ 40,  50,  68],
#         [ 41,  49,  72],
#         [ 42,  52,  76]],
#
#        [[  1,  28,  14],
#         [  2,  30,  13],
#         [  2,  30,  14],
#         ...,
#         [ 40,  50,  68],
#         [ 42,  50,  73],
#         [ 42,  52,  76]],
#
#        ...,
#
#        [[ 37,  47,  64],
#         [ 37,  47,  64],
#         [ 38,  48,  66],
#         ...,
#         [ 73,  87, 115],
#         [ 71,  85, 113],
#         [ 70,  84, 112]],
#
#        [[ 36,  47,  61],
#         [ 36,  47,  61],
#         [ 37,  47,  64],
#         ...,
#         [ 74,  88, 117],
#         [ 69,  86, 113],
#         [ 68,  85, 112]],
#
#        [[ 35,  46,  60],
#         [ 36,  47,  61],
#         [ 37,  47,  64],
# ...

# %%
plt.imshow(i_g)

# %%
plt.imshow(new_image)

# %%
n_img = img.dot([0.114,.587,.299])

# %%
n_img
# Out:
# array([[10.289,  9.702, 10.289, ..., 23.459, 23.758, 25.53 ],
#        [ 9.702, 10.289, 10.289, ..., 23.459, 23.171, 24.644],
#        [10.588, 10.876, 11.175, ..., 23.459, 23.758, 24.644],
#        ...,
#        [21.986, 21.986, 22.573, ..., 41.015, 39.542, 39.428],
#        [21.687, 21.687, 21.986, ..., 41.015, 40.015, 39.428],
#        [21.274, 21.687, 21.986, ..., 41.015, 40.015, 39.428]])

# %%
plt.imshow(n_img, cmap="gray")

# %%
plt.imshow(n_img)

# %%
output = np.zeros((img.shape[0], img.shape[1]))

# %%
output.shape
# Out:
# (2160, 3840)

# %%
for i in range(2161):
    for j in range(3841):
        output[i][j] = img[i][j][0]*0.114 + img[i][j][1]*0.587 + img[i][j][2]*0.299
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-275cc81f60a6> in <module>
#       1 for i in range(2161):
#       2     for j in range(3841):
# ----> 3         output[i][j] = img[i][j][0]*0.114 + img[i][j][1]*0.587 + img[i][j][2]*0.299
#
# IndexError: invalid index to scalar variable.

# %%
grey_img = np.zeros((img.shape[0],img.shape[1]))

for i in range(img.shape[0]):
    for j in range(img.shape[1]):
        k1 = img[i][j][0]
        k2 = img[i][j][1]
        k3 = img[i][j][2]
        k  = 0.114*k1 + 0.587*k2 + 0.299*k3
        grey_img[i][j] = k

# %%
plt.imshow(grey_img, cmap="gray")

# %%
cv2.imwrite("New_img.jpg", grey_img)
# Out:
# True

# %% [markdown]
# ### kernel operations

# %%
for rows in range(200):
    for col in range(grey_img.shape[1]):
        grey_img[rows][col] = 255

# %%
plt.imshow(grey_img, cmap="gray")

# %%
for cols in range(200):
    for rows in range(grey_img.shape[0]):
        grey_img[cols][rows] = 255

# %%
plt.imshow(grey_img, cmap="gray")

# %%
start = grey_img.shape[1]-200
for cols in range(start, grey_img.shape[1]):
    for rows in range(grey_img.shape[0]):
        grey_img[cols][rows] = 255
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-47-29b8d1f8e90d> in <module>
#       2 for cols in range(start, grey_img.shape[1]):
#       3     for rows in range(grey_img.shape[0]):
# ----> 4         grey_img[cols][rows] = 255
#
# IndexError: index 3640 is out of bounds for axis 0 with size 2160

# %%
for i in range(grey_img.shape[0]):
    for j in range(200):
        grey_img[i][j] = 255

# %%
plt.imshow(grey_img, cmap="gray")

# %%
for cols in range(200):
    for rows in range(grey_img.shape[0]-200,grey_img.shape[0]):
        grey_img[cols][rows] = 255

# %%
plt.imshow(grey_img, cmap="gray")

# %%
for i in range(grey_img.shape[0]):
    for j in range(257,287):
        grey_img[i][j] = 255

for i in range(350,380):
    for j in range(grey_img.shape[1]):
        grey_img[i][j] = 255

# %%
plt.imshow(grey_img, cmap="gray")
